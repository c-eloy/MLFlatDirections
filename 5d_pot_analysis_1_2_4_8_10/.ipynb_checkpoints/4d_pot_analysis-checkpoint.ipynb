# %%
import numpy as np 
import os 
import matplotlib.pyplot as plt
import tensorflow as tf
import time
import keras
from keras import layers,models,regularizers
from tensorflow.keras.callbacks import LearningRateScheduler
# Out:
# 2025-01-07 09:50:40.151341: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import train_test_split

# %%
import sys
import os

module_path = "/Users/bastienduboeuf/Documents/Recherche/MLForFlatDirections3D/MLFlatDirections"
sys.path.append(module_path)

import potentials as pot
import utils

# %%
#x3d = np.load('Points_None_10_21_47_seed550.npy')
#np.save('Points_19_12_24',x_4d.numpy())
x_4d = np.load('Points_19_12_24.npy')

# %%
# compute (||∇V||^2)
def grad_norm_squared(V, x ,factor=1):
    with tf.GradientTape() as tape:
        tape.watch(x)
        loss = V(x)  # compute V at each point
    gradients = tape.gradient(loss, x)  # compute ∇V at each point
    norm_squared = tf.reduce_sum(gradients**2, axis=1)  # ||∇V||^2 at each point
    return norm_squared * factor

def get_grad(V, x):
    with tf.GradientTape() as tape:
        tape.watch(x)
        loss = V(x)  # compute V at each point
    gradients = tape.gradient(loss, x)  # compute ∇V at each point
    return gradients

# %%
####### Gradient Descent #######

# %%
# randomly initialize the points
n_points = 10000
x_4d = tf.Variable(10*np.random.rand(n_points, 4)-5, dtype=tf.float32)

history_4d = []

# %%
# Oprimizer for the gradient descent

init_alpha=10**(-4)
alpha = init_alpha

optimizer = tf.optimizers.Adam(learning_rate=alpha)

# Learning loop 
loss_prev_step=10**8

#update_alpha = False
update_opt = True 
for step in range(1500):  
    with tf.GradientTape() as tape:
        loss = tf.reduce_sum(grad_norm_squared(pot.V4d_sugra_2_4_8_10, x_4d)) # minimize ||∇V||^2 for all points
    
    # Compute ||∇V||^2 with respect to x
    gradients = tape.gradient(loss, [x_4d])

    #if update_alpha and step % 300 == 0 and step != 0:
    #    alpha = alpha/2
    #    optimizer = tf.optimizers.Adam(learning_rate=alpha)
    if update_opt and step % 200 == 0 :
        print("Reinitializing the optimizer")
        optimizer = tf.optimizers.Adam(learning_rate=init_alpha)
    
    if step == 500:
        update_opt = False 
        optimizer.learning_rate.assign(0.00001)
    
    # Apply gradient descent for all points
    optimizer.apply_gradients(zip(gradients, [x_4d]))
    
    history_4d.append(loss)
    
    if step % 10 == 0:
        print(f"""Step {step}: ||∇V||^2 = {loss.numpy()} with learning rate {optimizer.get_config()["learning_rate"]}""")
        
    if np.log(loss.numpy())/np.log(10)<-10: 
        print("Converged enough") 
        print(f"Step {step}: ||∇V||^2 = {loss.numpy()}")
        break
# Out:
# Reinitializing the optimizer
# Step 0: ||∇V||^2 = 0.04750298708677292 with learning rate 9.999999747378752e-05
# Step 10: ||∇V||^2 = 634.8351440429688 with learning rate 9.999999747378752e-05
# Step 20: ||∇V||^2 = 138.0001983642578 with learning rate 9.999999747378752e-05
# Step 30: ||∇V||^2 = 10.006061553955078 with learning rate 9.999999747378752e-05
# Step 40: ||∇V||^2 = 10.702104568481445 with learning rate 9.999999747378752e-05
# Step 50: ||∇V||^2 = 7.738070487976074 with learning rate 9.999999747378752e-05
# Step 60: ||∇V||^2 = 2.452146530151367 with learning rate 9.999999747378752e-05
# Step 70: ||∇V||^2 = 0.7211426496505737 with learning rate 9.999999747378752e-05
# Step 80: ||∇V||^2 = 0.11583199352025986 with learning rate 9.999999747378752e-05
# Step 90: ||∇V||^2 = 0.14409422874450684 with learning rate 9.999999747378752e-05
# Step 100: ||∇V||^2 = 0.11936052143573761 with learning rate 9.999999747378752e-05
# ...

# %%
#utils.triangular_plot(x_4d.numpy())
utils.triangular_plot(x_4d)

# %%
plt.figure(figsize=(7,7))
plt.plot(np.log(history_4d)/np.log(10))
plt.show()

# %%
# filter the points

# %%
for i in range(10):
    print(np.sum(abs(pot.V4d_sugra_2_4_8_10(x_4d)+2)<10**-i))
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 9679
# 2277
# 2277
# 2277

# %%
maskx1noteq0 = abs(x_4d[:,0])>10**-2

# %%
#utils.triangular_plot(x_4d.numpy()[maskx1noteq0])
utils.triangular_plot(x_4d[maskx1noteq0])

# %%
#maskx1eq0 = abs(x_4d.numpy()[:,0])<10**-8
maskx1eq0 = abs(x_4d[:,0])<10**-8

# %%
utils.triangular_plot(x_4d[maskx1eq0])

# %%
##### Auto encoder analysis #####

# %%
x_4d = tf.Variable(x_4d)

# %%
set_train, set_test = train_test_split(x_4d.numpy(), test_size=0.1, random_state=1)

# %%
history_all = []

for i in range(4):
    
    this_latent_dim = i + 1
    input_dim = 4
    
    print(this_latent_dim)

    inputs = layers.Input(shape=(input_dim,))
    encoded = layers.Dense(128, activation='sigmoid')(inputs)
    encoded = layers.Dense(128, activation='sigmoid')(encoded)
    encoded = layers.Dense(this_latent_dim)(encoded)  

    decoded = layers.Dense(128, activation='sigmoid')(encoded)
    decoded = layers.Dense(128, activation='sigmoid')(decoded)
    decoded = layers.Dense(input_dim)(decoded)  

    this_autoencoder = keras.Model(inputs, decoded)
    this_autoencoder.compile(optimizer='adam', loss='mse')
    
    history_all.append(this_autoencoder.fit(set_train, set_train, epochs=5000, batch_size=100, shuffle=True, validation_data=(set_test,set_test)))
# Out:
# 1
# Epoch 1/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3354 - val_loss: 0.1831
# Epoch 2/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1568 - val_loss: 0.1007
# Epoch 3/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1017 - val_loss: 0.0943
# Epoch 4/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0953 - val_loss: 0.0906
# Epoch 5/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0954 - val_loss: 0.0898
# Epoch 6/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0945 - val_loss: 0.0897
# Epoch 7/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0936 - val_loss: 0.0876
# Epoch 8/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0912 - val_loss: 0.0860
# Epoch 9/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0914 - val_loss: 0.0854
# Epoch 10/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0909 - val_loss: 0.0833
# Epoch 11/5000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0887 - val_loss: 0.0820
# ...

# %%
plt.figure(figsize=(7,7))
for i in range(4):
    plt.plot(np.log(history_all[i].history['loss']))
plt.show()

# %%
history_mean_val = []
history_mean = []
for this_history in history_all: 
    this_mean_val = np.sum(this_history.history['val_loss'][-20:])/20
    this_mean = np.sum(this_history.history['loss'][-20:])/20
    history_mean_val.append(this_mean_val)
    history_mean.append(this_mean)

# %%
plt.figure(figsize=(7,7))
plt.scatter(range(4),np.log(history_mean)/np.log(10))
plt.scatter(range(4),np.log(history_mean_val)/np.log(10))
plt.show()

# %%
#3 d autoencoder

# %%
this_latent_dim = 3
input_dim = 4

inputs = layers.Input(shape=(input_dim,))
encoded = layers.Dense(64, activation='sigmoid')(inputs)
encoded = layers.Dense(64, activation='sigmoid')(encoded)
encoded = layers.Dense(this_latent_dim)(encoded)  

decoded = layers.Dense(64, activation='sigmoid')(encoded)
decoded = layers.Dense(64, activation='sigmoid')(decoded)
decoded = layers.Dense(input_dim)(decoded)  

autoencoder_4d = keras.Model(inputs, decoded)
autoencoder_4d.compile(optimizer='adam', loss='mse')
autoencoder_4d.fit(set_train, set_train, epochs=10000, batch_size=100, shuffle=True, validation_data=(set_test,set_test))
# Out:
# Epoch 1/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.2025 - val_loss: 0.1938
# Epoch 2/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1876 - val_loss: 0.1136
# Epoch 3/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1078 - val_loss: 0.0971
# Epoch 4/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0978 - val_loss: 0.0835
# Epoch 5/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0774 - val_loss: 0.0237
# Epoch 6/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0245 - val_loss: 0.0169
# Epoch 7/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0135 - val_loss: 0.0025
# Epoch 8/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 9/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 10/10000
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 11/10000
# ...

# %%
encoder_4d = keras.Model(inputs, encoded)
decoded_random4d = autoencoder_4d.predict(tf.Variable(4*(np.random.rand(10000,4)-0.5)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
utils.triangular_plot(decoded_random4d)

# %%
autoencoder_4d.save("autoencoder_4d_intdim_3.keras")

# %%
####### First family with x2 != 0

# %%
from matplotlib.colors import LogNorm

# %%
x4 = np.linspace(-1.,1.,1000)

# %%
plt.figure(figsize=(21,7))
plt.subplot(1,3,1)
plt.plot(x4,-np.log(1+(x4*2)**2),c='r')
counts,xbins,ybins,image = plt.hist2d(x_4d[maskx1noteq0][:,1],x_4d[maskx1noteq0][:,2],bins=100
                                      ,norm=LogNorm()
                                      ,cmap = plt.cm.rainbow)
plt.xlim(-1,1)

plt.subplot(1,3,2)
plt.plot(x4,2*2**.5 * x4,c='r')
counts,xbins,ybins,image = plt.hist2d(x_4d[maskx1noteq0][:,1],x_4d[maskx1noteq0][:,3],bins=100
                                      ,norm=LogNorm()
                                      ,cmap=plt.cm.rainbow)
plt.xlim(-1.01,1.01)

plt.subplot(1,3,3)
plt.plot(-np.log(1+(x4*2)**2),2*2**.5 * x4,c='r')
counts,xbins,ybins,image = plt.hist2d(x_4d[maskx1noteq0][:,2],x_4d[maskx1noteq0][:,3],bins=100
                                      ,norm=LogNorm()
                                      ,cmap=plt.cm.rainbow)
plt.xlim(-1.01,1.01)
plt.show()

# %%
x8 =  np.linspace(-1.,1.,1000)
plt.figure(figsize=(7,7))
plt.plot(x10,np.sqrt(2) * np.sqrt(-1 + np.exp(-x8)),c='r')
plt.plot(x10,-np.sqrt(2) * np.sqrt(-1 + np.exp(-x8)),c='r')
counts,xbins,ybins,image = plt.hist2d(x_4d[maskx1noteq0][:,2],x_4d[maskx1noteq0][:,3],bins=100
                                      ,norm=LogNorm()
                                      ,cmap = plt.cm.rainbow)
plt.xlim(-1,0)
plt.show()
# Out:
# /var/folders/7f/2871v4nx3pn_dph55xj6sxq40000gn/T/ipykernel_3342/1920208912.py:3: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x10,np.sqrt(2) * np.sqrt(-1 + np.exp(-x8)),c='r')
# /var/folders/7f/2871v4nx3pn_dph55xj6sxq40000gn/T/ipykernel_3342/1920208912.py:4: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x10,-np.sqrt(2) * np.sqrt(-1 + np.exp(-x8)),c='r')

# %%
#There is a factor of 2 between what found in mathematica and python ! x4->x4*2

# %%
####### Second family

# %%
x2 = np.linspace(-1.,1.,1000)
plt.figure(figsize=(7,7))
plt.plot(x2,2*np.log(1/(1-x2**2)),c='r')
counts,xbins,ybins,image = plt.hist2d(x_4d[maskx1noteq0][:,0],x_4d[maskx1noteq0][:,2],bins=100
                                      ,norm=LogNorm()
                                      ,cmap = plt.cm.rainbow)
plt.ylim(-1,1)
plt.show()
# Out:
# /var/folders/7f/2871v4nx3pn_dph55xj6sxq40000gn/T/ipykernel_3342/4068375539.py:3: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(x2,2*np.log(1/(1-x2**2)),c='r')

# %%
x2 = np.linspace(-1.,1.,1000)
plt.figure(figsize=(7,7))
plt.plot(x2,x2*(2-x2**2)**.5,c='r')
counts,xbins,ybins,image = plt.hist2d(x_4d[maskx1noteq0][:,0],x_4d[maskx1noteq0][:,1],bins=100
                                      ,norm=LogNorm()
                                      ,cmap = plt.cm.rainbow)
plt.ylim(-2,2)
plt.xlim(-2,2)
plt.show()
